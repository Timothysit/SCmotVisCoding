# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
neuronVisActivity = np.load('/Users/timothysit/Downloads/neuronVisActivity_SS041_2015-04-23.npy')

# %%
np.shape(neuronVisActivity)  # Trial x Time x Neuron
# Out:
# (30, 182, 383)

# %%
trial_idx = 0
num_neurons_to_plot = 10

fig, axs = plt.subplots(num_neurons_to_plot, 1, sharex=True, sharey=True)
fig.set_size_inches(4, 12)
[axs[x].plot(neuronVisActivity[trial_idx, :, x]) for x in np.arange(0, num_neurons_to_plot)]
# Out:
# [[<matplotlib.lines.Line2D at 0x12b8eb4c0>],
# ...
